# %% [markdown]
# # Data in the notebook got from anthropologist [Stanislav Drobyshevsky](https://vk.com/id15342645)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
from utils_01 import init_param, model  # , compute_cost, init_adam, adam_optimizer, forward_prop, backward_prop

sns.set_style("whitegrid")

# %%
path = os.path.join("./", "data_Drob_primates.xlsx")
dataset_innerhead = pd.read_excel(path, sheet_name=0)  # , engine="openpyxl"
dataset_head = pd.read_excel(path, sheet_name=1)  # , engine="openpyxl"
dataset_timechanges = pd.read_excel(path, sheet_name=2)  # , engine="openpyxl"
# dataset_timechanges

# %% [markdown]
# # Body weight vs inner-head volume analysis
# ## Primates
# ## *Data view*

# %%
cols = ['длина черепа', 'объём мозговой полости, см3', 'EEQ']

dataset_innerhead[cols] = dataset_innerhead[cols].apply(lambda x: x.str.extract(r'(\d+,\d+)', expand=False))
dataset_innerhead[cols] = dataset_innerhead[cols].apply(lambda x: x.str.replace(',', '.'))
dataset_innerhead[cols] = dataset_innerhead[cols].astype("float64")

sns.pairplot(dataset_innerhead)
plt.show()

# %%
m = dataset_innerhead.shape[0]
X = dataset_innerhead["масса тела, г"]
y = dataset_innerhead["объём мозговой полости, см3"]
sns.jointplot(x=X, y=y)
plt.show()

# %%
X = np.concatenate((np.zeros((m, 1)), X.to_numpy().reshape(-1, 1)), axis=1)
# X = X.to_numpy().reshape(-1, 1)
y = y.to_numpy().reshape((-1, 1))
theta = init_param(*X.shape)  # np.zeros(X.shape[1], 1)
# W, b = parameters["W1"], parameters["b1"]

# iter = 1500
# alpha = 0.01
theta, history = model(X, y)

# %%
# # J = compute_cost(X, y, W)
# layers_dims = [X.shape[1], 1]
# parameters, costs_history, cache = model(X, y, layers_dims)
# Out:
# backprop
# shapes X, W, b, y:
#  (76, 2) (1, 2) (1, 1) (76, 1)
# backprop
# shapes dW, db:
#  (2, 1) (1, 1)
# adam_opt
# shapes: v, grads (1, 2) (2, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9c71c30d0412> in <module>
#       1 # J = compute_cost(X, y, W)
#       2 layers_dims = [X.shape[1], 1]
# ----> 3 parameters = model(X, y, layers_dims)
#
# C:\prog\projects\ML\Regression\BrainSize\Drob\utils.py in model(X, Y, layers_dims, learning_rate, beta1, beta2, epsilon, num_epochs, print_cost)
#     120         grads = backward_prop(X, Y, caches)
#     121         t += 1
# --> 122         parameters, v, s = adam_optimizer(parameters, grads, v, s, t,
#     123                                           learning_rate, beta1, beta2, epsilon)
#     124
#
# C:\prog\projects\ML\Regression\BrainSize\Drob\utils.py in adam_optimizer(parameters, grads, v, s, t, learning_rate, beta1, beta2, epsilon, mod)
#      66             s[dWb] = beta2 * s[dWb] + (1 - beta2) * np.square(grads[dWb])
#      67             s_corrected[dWb] = s[dWb] / (1 - np.power(beta2, t))
# ---> 68             parameters[Wb] -= learning_rate * v_corrected[dWb]
#      69             parameters[Wb] /= np.sqrt(s_corrected[dWb]) + epsilon
#      70
#
# ValueError: non-broadcastable output operand with shape (1,2) doesn't match the broadcast shape (2,2)

# %%
# from pdb import set_trace

# set_trace()

# %%
# costs_history[:]

# %%
# parameters

# %%
# a = {"A" : 1, "B": 2}
# b = {"c" : 3, "d": 4}
# for i, j in zip(a, b):
#     print(i, j)
