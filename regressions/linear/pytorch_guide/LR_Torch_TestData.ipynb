# %%
import torch
from torch.autograd import Variable
from torch.nn import functional as F
import numpy as np

# %%
inputs =  np.array([[73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70], 
               [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70], 
               [73, 67, 43], [91, 88, 64], [87, 134, 58], [102, 43, 37], [69, 96, 70]], dtype='float32')

targets = np.array([[56, 70], [81, 101], [119, 133], [22, 37], [103, 119], 
              [56, 70], [81, 101], [119, 133], [22, 37], [103, 119], 
              [56, 70], [81, 101], [119, 133], [22, 37], [103, 119]], dtype='float32')

inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

# %%
from torch.utils.data import TensorDataset, DataLoader

# Define dataset
train_ds = TensorDataset(inputs, targets)

# Define data loader
batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle=True)

# Define model
model = torch.nn.Linear(3, 2)

# Define optimizer
opt = torch.optim.SGD(model.parameters(), lr=1e-5)

# Define loss function
loss_fn = F.mse_loss

# Define a utility function to train the model
def fit(num_epochs, model, loss_fn, opt):
    global train_dl
    for epoch in range(num_epochs):
        for xb, yb in train_dl:
            # Generate predictions
            pred = model(xb)
            loss = loss_fn(pred, yb)
            
            # Perform gradient descent
            loss.backward()
            opt.step()
            opt.zero_grad()
        print('Training loss: ', loss_fn(model(inputs), targets))
        
# Train the model for 100 epochs
fit(100, model, loss_fn, opt)

# Generate predictions
preds = model(inputs)
# Out:
# Training loss:  tensor(1162.1400, grad_fn=<MseLossBackward>)
# Training loss:  tensor(447.9410, grad_fn=<MseLossBackward>)
# Training loss:  tensor(229.7907, grad_fn=<MseLossBackward>)
# Training loss:  tensor(148.5965, grad_fn=<MseLossBackward>)
# Training loss:  tensor(125.6239, grad_fn=<MseLossBackward>)
# Training loss:  tensor(115.5944, grad_fn=<MseLossBackward>)
# Training loss:  tensor(109.3663, grad_fn=<MseLossBackward>)
# Training loss:  tensor(105.5332, grad_fn=<MseLossBackward>)
# Training loss:  tensor(102.2107, grad_fn=<MseLossBackward>)
# Training loss:  tensor(98.7400, grad_fn=<MseLossBackward>)
# Training loss:  tensor(95.5221, grad_fn=<MseLossBackward>)
# Training loss:  tensor(92.4396, grad_fn=<MseLossBackward>)
# Training loss:  tensor(89.4497, grad_fn=<MseLossBackward>)
# Training loss:  tensor(86.5471, grad_fn=<MseLossBackward>)
# Training loss:  tensor(83.8292, grad_fn=<MseLossBackward>)
# Training loss:  tensor(81.2375, grad_fn=<MseLossBackward>)
# Training loss:  tensor(78.5882, grad_fn=<MseLossBackward>)
# Training loss:  tensor(76.1677, grad_fn=<MseLossBackward>)
# Training loss:  tensor(73.8216, grad_fn=<MseLossBackward>)
# Training loss:  tensor(71.6096, grad_fn=<MseLossBackward>)
# Training loss:  tensor(69.3396, grad_fn=<MseLossBackward>)
# Training loss:  tensor(67.2702, grad_fn=<MseLossBackward>)
# Training loss:  tensor(65.1853, grad_fn=<MseLossBackward>)
# Training loss:  tensor(63.2004, grad_fn=<MseLossBackward>)
# Training loss:  tensor(61.3180, grad_fn=<MseLossBackward>)
# Training loss:  tensor(59.4962, grad_fn=<MseLossBackward>)
# Training loss:  tensor(57.7853, grad_fn=<MseLossBackward>)
# Training loss:  tensor(56.0233, grad_fn=<MseLossBackward>)
# Training loss:  tensor(54.4125, grad_fn=<MseLossBackward>)
# Training loss:  tensor(52.8706, grad_fn=<MseLossBackward>)
# Training loss:  tensor(51.3669, grad_fn=<MseLossBackward>)
# Training loss:  tensor(49.8923, grad_fn=<MseLossBackward>)
# Training loss:  tensor(48.5078, grad_fn=<MseLossBackward>)
# Training loss:  tensor(47.1596, grad_fn=<MseLossBackward>)
# Training loss:  tensor(45.8556, grad_fn=<MseLossBackward>)
# Training loss:  tensor(44.6049, grad_fn=<MseLossBackward>)
# Training loss:  tensor(43.3833, grad_fn=<MseLossBackward>)
# Training loss:  tensor(42.2070, grad_fn=<MseLossBackward>)
# Training loss:  tensor(41.0824, grad_fn=<MseLossBackward>)
# Training loss:  tensor(40.0034, grad_fn=<MseLossBackward>)
# Training loss:  tensor(38.9606, grad_fn=<MseLossBackward>)
# Training loss:  tensor(37.9757, grad_fn=<MseLossBackward>)
# Training loss:  tensor(36.9823, grad_fn=<MseLossBackward>)
# Training loss:  tensor(36.0668, grad_fn=<MseLossBackward>)
# Training loss:  tensor(35.1154, grad_fn=<MseLossBackward>)
# Training loss:  tensor(34.2459, grad_fn=<MseLossBackward>)
# Training loss:  tensor(33.4007, grad_fn=<MseLossBackward>)
# Training loss:  tensor(32.5753, grad_fn=<MseLossBackward>)
# Training loss:  tensor(31.7730, grad_fn=<MseLossBackward>)
# Training loss:  tensor(30.9993, grad_fn=<MseLossBackward>)
# Training loss:  tensor(30.2641, grad_fn=<MseLossBackward>)
# Training loss:  tensor(29.5588, grad_fn=<MseLossBackward>)
# Training loss:  tensor(28.8608, grad_fn=<MseLossBackward>)
# Training loss:  tensor(28.2029, grad_fn=<MseLossBackward>)
# Training loss:  tensor(27.5648, grad_fn=<MseLossBackward>)
# Training loss:  tensor(26.9485, grad_fn=<MseLossBackward>)
# Training loss:  tensor(26.3583, grad_fn=<MseLossBackward>)
# Training loss:  tensor(25.7722, grad_fn=<MseLossBackward>)
# Training loss:  tensor(25.2219, grad_fn=<MseLossBackward>)
# Training loss:  tensor(24.6608, grad_fn=<MseLossBackward>)
# Training loss:  tensor(24.1270, grad_fn=<MseLossBackward>)
# Training loss:  tensor(23.6192, grad_fn=<MseLossBackward>)
# Training loss:  tensor(23.1349, grad_fn=<MseLossBackward>)
# Training loss:  tensor(22.6676, grad_fn=<MseLossBackward>)
# Training loss:  tensor(22.2132, grad_fn=<MseLossBackward>)
# Training loss:  tensor(21.7804, grad_fn=<MseLossBackward>)
# Training loss:  tensor(21.3590, grad_fn=<MseLossBackward>)
# Training loss:  tensor(20.9489, grad_fn=<MseLossBackward>)
# Training loss:  tensor(20.5567, grad_fn=<MseLossBackward>)
# Training loss:  tensor(20.1775, grad_fn=<MseLossBackward>)
# Training loss:  tensor(19.8062, grad_fn=<MseLossBackward>)
# Training loss:  tensor(19.4516, grad_fn=<MseLossBackward>)
# Training loss:  tensor(19.1012, grad_fn=<MseLossBackward>)
# Training loss:  tensor(18.7598, grad_fn=<MseLossBackward>)
# Training loss:  tensor(18.4329, grad_fn=<MseLossBackward>)
# Training loss:  tensor(18.1235, grad_fn=<MseLossBackward>)
# Training loss:  tensor(17.8028, grad_fn=<MseLossBackward>)
# Training loss:  tensor(17.5077, grad_fn=<MseLossBackward>)
# Training loss:  tensor(17.2269, grad_fn=<MseLossBackward>)
# Training loss:  tensor(16.9533, grad_fn=<MseLossBackward>)
# Training loss:  tensor(16.6787, grad_fn=<MseLossBackward>)
# Training loss:  tensor(16.4477, grad_fn=<MseLossBackward>)
# Training loss:  tensor(16.1672, grad_fn=<MseLossBackward>)
# Training loss:  tensor(15.9154, grad_fn=<MseLossBackward>)
# Training loss:  tensor(15.6764, grad_fn=<MseLossBackward>)
# Training loss:  tensor(15.4469, grad_fn=<MseLossBackward>)
# Training loss:  tensor(15.2248, grad_fn=<MseLossBackward>)
# Training loss:  tensor(15.0064, grad_fn=<MseLossBackward>)
# Training loss:  tensor(14.7948, grad_fn=<MseLossBackward>)
# Training loss:  tensor(14.5913, grad_fn=<MseLossBackward>)
# Training loss:  tensor(14.3928, grad_fn=<MseLossBackward>)
# Training loss:  tensor(14.2000, grad_fn=<MseLossBackward>)
# Training loss:  tensor(14.0074, grad_fn=<MseLossBackward>)
# Training loss:  tensor(13.8409, grad_fn=<MseLossBackward>)
# Training loss:  tensor(13.6461, grad_fn=<MseLossBackward>)
# Training loss:  tensor(13.4758, grad_fn=<MseLossBackward>)
# Training loss:  tensor(13.3362, grad_fn=<MseLossBackward>)
# Training loss:  tensor(13.1392, grad_fn=<MseLossBackward>)
# Training loss:  tensor(12.9818, grad_fn=<MseLossBackward>)
# Training loss:  tensor(12.8266, grad_fn=<MseLossBackward>)
